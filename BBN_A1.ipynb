# %%
import matplotlib.pyplot as plt
import numpy as np
from math import*

eta=np.geomspace(10**(-12.1),10**(-7),1000)
eta_1=[x*(10**(10)) for x in eta]

T_c=0.03/((1+np.log(eta_1)/7)**3)
T_n=0.25/(1+np.log(eta_1)/35)
plt.semilogx(eta,T_c,label=r'$T_{c}$',color='red')
plt.semilogx(eta,T_n,label=r'$T_{nuclei}$',color='blue')
plt.axhline(y=0.02,color='darkblue',linestyle='--',label=r'$T_{n}$')
plt.axhline(y=1,color='green',linestyle='dotted',label=r'$T_{F}$')
plt.annotate(r'$NSE+\beta$ Equilibrium',xy=(10**(-10.7),1.005))


plt.xlabel(r'$\eta$')
plt.ylabel(r'$T/MeV$')
plt.grid(True)
plt.legend()
plt.title("BBN Temperature V/S n-p ratio")
plt.tight_layout()
plt.figure(figsize=(8, 6), dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

eta = np.geomspace(10**(-12), 10**(-7), 100)
eta_1 = [x * (10**(10)) for x in eta]

T_c = 0.03 / ((1 + np.log(eta_1) / 7)**3)
T_n = 0.25 / (1 + np.log(eta_1) / 35)

plt.figure(figsize=(8, 6), dpi=300)  # Increase the size and resolution of the figure

plt.semilogx(eta, T_c, label=r'$T_{c}$', color='blue')  # Change line color to blue
plt.semilogx(eta, T_n, label=r'$T_{n}$', color='red')  # Change line color to red

plt.xlabel(r'$\eta$', fontsize=14)  # Increase the font size of x-axis label
plt.ylabel(r'$T$/MeV', fontsize=14)  # Increase the font size of y-axis label

plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)  # Add grid with custom properties

plt.legend(fontsize=12)  # Increase the font size of the legend

plt.title("BBN Temperature vs. n-p ratio", fontsize=16)  # Increase the font size of the title

plt.tight_layout()  # Improve the spacing of the plot elements

plt.savefig("bbn_plot.png", dpi=300)  # Save the plot with higher resolution

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

eta = np.geomspace(10**(-12), 10**(-7), 100)
eta_1 = [x * (10**(10)) for x in eta]

T_c = 0.03 / ((1 + np.log(eta_1) / 7)**3)
T_n = 0.25 / (1 + np.log(eta_1) / 35)

fig, ax1 = plt.subplots(figsize=(8, 6), dpi=300)  # Increase the size and resolution of the figure

color1 = 'tab:red'
ax1.semilogx(eta, T_c, label=r'$T_{c}$', color=color1)  # Change line color to red
ax1.set_xlabel(r'$\eta$', fontsize=14)  # Increase the font size of x-axis label
ax1.set_ylabel(r'$T$/MeV', fontsize=14, color=color1)  # Increase the font size of y-axis label
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()
color2 = 'tab:blue'
ax2.invert_yaxis()  # Invert the y-axis for time
ax2.set_ylabel('Time', fontsize=14, color=color2)  # Increase the font size of the y-axis label
ax2.tick_params(axis='y', labelcolor=color2)

ax1.semilogx(eta, T_n, label=r'$T_{n}$', color=color2)  # Change line color to blue

plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)  # Add grid with custom properties

plt.legend(fontsize=12)  # Increase the font size of the legend

plt.title("BBN Temperature vs. n-p ratio", fontsize=16)  # Increase the font size of the title

plt.tight_layout()  # Improve the spacing of the plot elements

plt.savefig("bbn_plot.png", dpi=300)  # Save the plot with higher resolution

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

eta = np.geomspace(10**(-12), 10**(-7), 100)
eta_1 = [x * (10**(10)) for x in eta]

T_c = 0.03 / ((1 + np.log(eta_1) / 7)**3)
T_n = 0.25 / (1 + np.log(eta_1) / 35)

fig, ax1 = plt.subplots(figsize=(8, 6), dpi=300)  # Increase the size and resolution of the figure

color1 = 'tab:red'
ax1.semilogx(eta, T_c, label=r'$T_{c}$', color=color1)  # Change line color to red
ax1.set_xlabel(r'$\eta$', fontsize=14)  # Increase the font size of x-axis label
ax1.set_ylabel(r'$T$/MeV', fontsize=14, color=color1)  # Increase the font size of y-axis label
ax1.tick_params(axis='y', labelcolor=color1)



ax2 = ax1.twinx()
ax2.invert_yaxis()  # Invert the y-axis for time
ax2.set_ylabel('Time', fontsize=14, color=color2)  # Remove the label for the time axis
ax2.tick_params(axis='y', labelcolor='none')  # Remove the tick labels for the time axis

ax1.semilogx(eta, T_n, label=r'$T_{n}$', color='tab:blue')  # Change line color to blue

plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)  # Add grid with custom properties

ax1.set_title("BBN Temperature vs. n-p ratio", fontsize=16)  # Set title for the temperature plot

plt.tight_layout()  # Improve the spacing of the plot elements

  # Save the plot with higher resolution

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
eta = np.geomspace(10**(-12.1), 10**(-7), 1000)
eta_1 = [x * (10**(10)) for x in eta]
T_c = 0.03 / ((1 + np.log(eta_1) / 7) ** 3)
T_n = 0.25 / (1 + np.log(eta_1) / 35)

# Plot
plt.semilogx(eta, T_c, label=r'$T_{\mathrm{c}}$')
plt.semilogx(eta, T_n, label=r'$T_{\mathrm{nuclei}}$')
plt.axhline(y=0.02, color='red', linestyle='--', label=r'$T_{\mathrm{n}}$')
plt.axhline(y=1, color='green', linestyle='dotted', label=r'$T_{\mathrm{F}}$')
plt.annotate(r'$NSE+\beta$ Equilibrium', xy=(10**(-10.7), 1.005))

# Axes labels and title
plt.xlabel(r'$\eta$')
plt.ylabel(r'$T/\mathrm{MeV}$')
plt.title("BBN Temperature vs. n-p Ratio")

# Grid and legend
plt.grid(True)
plt.legend()

# Adjust layout and figure size
plt.tight_layout()
plt.figure(figsize=(8, 6), dpi=300)

# Save or display the plot
 # Save the plot as an image
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import*

eta = np.geomspace(10**(-12.1), 10**(-7), 1000)
eta_1 = [x*(10**(10)) for x in eta]

T_c = 0.03 / ((1 + np.log(eta_1) / 7) ** 3)
T_n = 0.25 / (1 + np.log(eta_1) / 35)

plt.semilogx(eta, T_c, label=r'$T_{c}$')
plt.semilogx(eta, T_n, label=r'$T_{nuclei}$')
plt.axhline(y=0.02, color='red', linestyle='--', label=r'$T_{n}$')
plt.axhline(y=1, color='green', linestyle='dotted', label=r'$T_{F}$')

plt.annotate('NSE Equilibrium', xy=(10**(-11.5), 1.2), xytext=(10**(-11.5), 1.2), color='green', ha='left')


plt.xlabel(r'$\eta$')
plt.ylabel(r'$T/MeV$')
plt.grid(True)
plt.legend()
plt.title("BBN Temperature V/S n-p ratio")
plt.tight_layout()

plt.show()

# %% [markdown]
# On a $log-log$ scale, <mark>plot the densities of radiation, baryonic matter, dark matter and vacuum energy as a function of inverse scale factor, starting with a value of $R^{-1}=10^{-10}$ and ending at $R^{-1} = 1$</mark>. Use the current $(R = 1)$ values as boundary conditions.
#
# * Radiation dominated Universe $\rho=CR^{-4}$
# * Baryonic Matter dominated Universe $\rho=CR^{-3}$
# * Universe dominated by Vacuum Energy $$
# * Dark matter dominated Universe
# ** Source [ASTROPHYSICAL CONSTANTS AND PARAMETERS](https://pdg.lbl.gov/2014/reviews/rpp2014-rev-astrophysical-constants.pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt

c_r = 2.60 * 10**(-10)
c_b = 2.34 * 10**(-7)
c_d = 1.25 * 10**(-6)
c_v=3.2*10**(-6)
r = np.geomspace(10**(-10), 10**(0), 10000)
p1 = c_r * r**(-4)
p2 = c_b * r**(-3)
p3 = c_d*r**(-3)
p4=c_v

plt.xscale("log")
plt.yscale("log")
plt.plot(x,y,'go')
plt.plot(r,p1,color="red",label=r'$\rho_{r} $ (radiation density)')
plt.plot(r,p2,color="blue",label=r'$\rho_{b}$ (baryonic density)')
plt.plot(r,p3,color="magenta",label=r'$\rho_{d}$ (dark matter density)')
plt.axhline(y=p4,linestyle="dotted",label=r'$\rho_{v}$ (dark matter density)',color="black")
plt.ylabel(r'$\rho$')
plt.xlabel(r'$R$')


plt.grid(True)
plt.legend()
plt.tight_layout()

# %%
c_m=c_b+c_d
p5 = c_m * r**(-3)
plt.xscale("log")
plt.yscale("log")
plt.plot(r,p1,color="red",label=r'$\rho_{r} $ (radiation density)')
plt.plot(r,p5,color="blue",label=r'$\rho_{m} $ (matter density)')
plt.axhline(y=p4,linestyle="dotted",label=r'$\rho_{v}$ (dark matter density)',color="black")
plt.ylabel(r'$\rho$')
plt.xlabel(r'$R$')
plt.plot(x2,y2,'go')
plt.annotate(('(1.75e-04,2.76e+05)'),(x2,y2))
plt.axhline(y=p4,linestyle="dotted",label=r'$\rho_{v}$ (dark matter density)',color="black")

plt.grid(True)
plt.legend()
plt.tight_layout()

# %%
c_r = 2.60 * 10**(-10)
c_b = 2.34 * 10**(-7)

float_number=c_r/c_b
exp_number = "{:e}".format(float_number)

# %%
print(exp_number)
# Out:
# 1.111111e-03

# %%
print(c_r*(float_number**-4))
# Out:
# 170.5859999999999

# %%
y=c_r*(float_number**(-4))
x=float_number

# %%
print(x1)
# Out:
# 170.5859999999999

# %%
print(x2)
# Out:
# 170.58599999999987

# %%
f_2=c_r/c_m
y2=c_r*(f_2**(-4))

# %%
x2=f_2

# %%
print(x2,y2)
# Out:
# 0.00017520215633423184 275940.5717760581

# %%
e2 = "{:e}".format(x2)

# %%
e3="{:e}".format(y2)

# %%
print(e2,e3)
# Out:
# 1.752022e-04 2.759406e+05

# %% [markdown]
# ## Note
# As we talk there is some evidence of $\Lambda$ , which seems to dominate at present epoch and its about 2 times more than the matter density
